# %%
import os
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
pd.set_option('display.max_rows', 200)
plotting_context = "paper"
default_palette = "colorblind"
a_palette = sns.color_palette("YlOrRd", 2)
b_palette = sns.color_palette("icefire", 2)
c_palette = sns.color_palette("tab20", 2)
models_palette = sns.color_palette("Spectral",2)
font_scale = 1.4
sns.set(font_scale=font_scale, context=plotting_context)
sns.set(rc={"figure.dpi":300, 'savefig.dpi':300})

def show_barplot_values(ax, decimals=2):
    
    max_y = 0
    for (p_ix, p) in enumerate(ax.patches):
        #if p_ix >= (len(ax.patches) / 2):
        #p_ix = p_ix - (len(ax.patches) / 2)
        _x = p.get_x() + p.get_width() / 2
        _y = p.get_y() + (p.get_height() * 1.05)
        max_y = max(max_y, _y)
        if decimals == 2:
            value = '{:.2f}'.format(_y)
        elif decimals == 1:
            value = '{:.1f}'.format(_y)
        elif decimals == 0:
            value = '{:.0f}'.format(_y)
        ax.text(_x, _y, value, ha="center")
        
    visualized_max_y = max_y * 1.10
    ax.set_ylim([0, visualized_max_y])

# %% [markdown]
# ### FLAN T5 Model Throughput

# %%
throughput_dict = {
    "model_name": [],
    "minibatch_size": [],
    "tokens_per_s": []

}

def add_to_throughput_dict(model, minibatch_size, tokens_per_s):
    throughput_dict["model_name"].append(model)
    throughput_dict["minibatch_size"].append(minibatch_size)
    throughput_dict["tokens_per_s"].append(tokens_per_s)

add_to_throughput_dict(model="google/flan-t5-small", minibatch_size=1   , tokens_per_s=287.046447)
add_to_throughput_dict(model="google/flan-t5-small", minibatch_size=8   , tokens_per_s=370.270828)
add_to_throughput_dict(model="google/flan-t5-small", minibatch_size=16  , tokens_per_s=592.968843)
add_to_throughput_dict(model="google/flan-t5-small", minibatch_size=32  , tokens_per_s=1104.413837)
add_to_throughput_dict(model="google/flan-t5-small", minibatch_size=64  , tokens_per_s=2146.452256)
add_to_throughput_dict(model="google/flan-t5-small", minibatch_size=128 , tokens_per_s=4283.432291)
add_to_throughput_dict(model="google/flan-t5-base",  minibatch_size=1  ,  tokens_per_s=417.595299)
add_to_throughput_dict(model="google/flan-t5-base",  minibatch_size=8  ,  tokens_per_s=900.732014)
add_to_throughput_dict(model="google/flan-t5-base",  minibatch_size=16 ,  tokens_per_s=1638.849320)
add_to_throughput_dict(model="google/flan-t5-base",  minibatch_size=32 ,  tokens_per_s=3181.525497)
add_to_throughput_dict(model="google/flan-t5-large", minibatch_size=1  ,  tokens_per_s=893.436509  )
add_to_throughput_dict(model="google/flan-t5-large", minibatch_size=8  ,  tokens_per_s=2506.042086 )
add_to_throughput_dict(model="google/flan-t5-large", minibatch_size=16 ,  tokens_per_s=17639.401975)

throughput_df = pd.DataFrame(throughput_dict)
throughput_df
# Out:
#               model_name  minibatch_size  tokens_per_s
# 0   google/flan-t5-small               1    287.046447
# 1   google/flan-t5-small               8    370.270828
# 2   google/flan-t5-small              16    592.968843
# 3   google/flan-t5-small              32   1104.413837
# 4   google/flan-t5-small              64   2146.452256
# 5   google/flan-t5-small             128   4283.432291
# 6    google/flan-t5-base               1    417.595299
# 7    google/flan-t5-base               8    900.732014
# 8    google/flan-t5-base              16   1638.849320
# 9    google/flan-t5-base              32   3181.525497
# 10  google/flan-t5-large               1    893.436509
# 11  google/flan-t5-large               8   2506.042086
# 12  google/flan-t5-large              16  17639.401975

# %%
#from transformers import AutoConfig, T5ForConditionalGeneration
#config = AutoConfig.from_pretrained("google/flan-t5-small")
#model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-xl")
#print(sum(p.numel() for p in model.parameters() if p.requires_grad))

# %%
model_size_dict = {
    "model_name": [],
    "params": [],
    "n_layers": [],  # total layer count
    "d_model": [], # embedding size
    "d_ff": [],    # feedforward output size
    "n_attention_heads": [], # attention head count
    "seq_len": []
}

def add_model_size(name, params, layers, d_model, d_ff, d_kv, heads, seq_len):
    model_size_dict["model_name"].append(name)
    model_size_dict["params"].append(params)
    model_size_dict["n_layers"].append(layers)
    model_size_dict["d_model"].append(d_model)
    model_size_dict["d_ff"].append(d_ff)
    model_size_dict["n_attention_heads"].append(heads)
    model_size_dict["seq_len"].append(seq_len)

add_model_size(name="google/flan-t5-small", params=76961152,   layers=8,  d_model=512,  d_ff=1024,  d_kv=64,  heads=8,  seq_len=512)
add_model_size(name="google/flan-t5-base",  params=247577856,  layers=12, d_model=768,  d_ff=2048,  d_kv=64,  heads=12, seq_len=512)
add_model_size(name="google/flan-t5-large", params=783150080,  layers=24, d_model=1024, d_ff=2816,  d_kv=64,  heads=16, seq_len=512)
add_model_size(name="google/flan-t5-xl",    params=2849757184, layers=24, d_model=2048, d_ff=5120,  d_kv=64,  heads=32, seq_len=512)

t5_model_df = pd.DataFrame(t5_model_size_dict)
t5_model_df
# Out:
#              model_name      params  n_layers  d_model  d_ff  \
# 0  google/flan-t5-small    76961152         8      512  1024
# 1   google/flan-t5-base   247577856        12      768  2048
# 2  google/flan-t5-large   783150080        24     1024  2816
# 3     google/flan-t5-xl  2849757184        24     2048  5120
#
#    n_attention_heads  seq_len
# 0                  8      512
# 1                 12      512
# 2                 16      512
# 3                 32      512

# %%
full_df = throughput_df.merge(t5_model_df, left_on="model_name", right_on="model_name").copy()
full_df
# Out:
#               model_name  minibatch_size  tokens_per_s     params  n_layers  \
# 0   google/flan-t5-small               1    287.046447   76961152         8
# 1   google/flan-t5-small               8    370.270828   76961152         8
# 2   google/flan-t5-small              16    592.968843   76961152         8
# 3   google/flan-t5-small              32   1104.413837   76961152         8
# 4   google/flan-t5-small              64   2146.452256   76961152         8
# 5   google/flan-t5-small             128   4283.432291   76961152         8
# 6    google/flan-t5-base               1    417.595299  247577856        12
# 7    google/flan-t5-base               8    900.732014  247577856        12
# 8    google/flan-t5-base              16   1638.849320  247577856        12
# 9    google/flan-t5-base              32   3181.525497  247577856        12
# 10  google/flan-t5-large               1    893.436509  783150080        24
# 11  google/flan-t5-large               8   2506.042086  783150080        24
# 12  google/flan-t5-large              16  17639.401975  783150080        24
#
#     d_model  d_ff  n_attention_heads  seq_len
# 0       512  1024                  8      512
# 1       512  1024                  8      512
# 2       512  1024                  8      512
# 3       512  1024                  8      512
# 4       512  1024                  8      512
# 5       512  1024                  8      512
# 6       768  2048                 12      512
# 7       768  2048                 12      512
# 8       768  2048                 12      512
# 9       768  2048                 12      512
# 10     1024  2816                 16      512
# 11     1024  2816                 16      512
# 12     1024  2816                 16      512

# %%
theoretical_hardware_fp16_flops = 170/2 * 1e12 # Orin AGX (INT8 / 2)
#theoretical_hardware_fp16_flops = 77.97  # A100 SXM4 80G (FP16)
#theoretical_hardware_fp16_flops = 311.84 # A100 SXM4 80G (BF16)

def calculate_mfu(row):
    tokens_per_s = row["tokens_per_s"]
    params  = row["params"]
    layers  = row["n_layers"]
    heads   = row["n_attention_heads"]
    emb_dim = row["d_model"]
    
    N = params
    L = layers
    H = heads
    Q = emb_dim / heads
    T = 512
    
    ff_flops = 2 * N
    bw_flops = 4 * N
    attention_flops = 12 * L * H * Q * T
    flops_per_token = ff_flops + bw_flops + attention_flops
    
    theoretical_model_throughput_tokens_per_second = theoretical_hardware_fp16_flops / flops_per_token
    
    mfu_in_percent = tokens_per_s / theoretical_model_throughput_tokens_per_second * 100
    print(f"model: {row['model_name']}, mb: {row['minibatch_size']}")
    print(f"      fpt: {flops_per_token}")
    print(f" theo_fpt: {theoretical_model_throughput_tokens_per_second}")
    print(f"    tok/s: {tokens_per_s}")
    print(f"      mfu: {round(mfu_in_percent,2)}%")
    return mfu_in_percent

# %%
full_df["mfu"] = full_df.apply(calculate_mfu, axis=1)
# Out:
# model: google/flan-t5-small, mb: 1
#       fpt: 486932736.0
#  theo_fpt: 174562.09803893734
#     tok/s: 287.046447
#       mfu: 0.16%
# model: google/flan-t5-small, mb: 8
#       fpt: 486932736.0
#  theo_fpt: 174562.09803893734
#     tok/s: 370.270828
#       mfu: 0.21%
# model: google/flan-t5-small, mb: 16
#       fpt: 486932736.0
#  theo_fpt: 174562.09803893734
#     tok/s: 592.968843
#       mfu: 0.34%
# model: google/flan-t5-small, mb: 32
#       fpt: 486932736.0
#  theo_fpt: 174562.09803893734
#     tok/s: 1104.413837
#       mfu: 0.63%
# model: google/flan-t5-small, mb: 64
#       fpt: 486932736.0
#  theo_fpt: 174562.09803893734
#     tok/s: 2146.452256
#       mfu: 1.23%
# model: google/flan-t5-small, mb: 128
#       fpt: 486932736.0
#  theo_fpt: 174562.09803893734
#     tok/s: 4283.432291
#       mfu: 2.45%
# model: google/flan-t5-base, mb: 1
#       fpt: 1542090240.0
#  theo_fpt: 55119.990902737314
#     tok/s: 417.595299
#       mfu: 0.76%
# model: google/flan-t5-base, mb: 8
#       fpt: 1542090240.0
#  theo_fpt: 55119.990902737314
#     tok/s: 900.732014
#       mfu: 1.63%
# model: google/flan-t5-base, mb: 16
#       fpt: 1542090240.0
#  theo_fpt: 55119.990902737314
#     tok/s: 1638.84932
#       mfu: 2.97%
# model: google/flan-t5-base, mb: 32
#       fpt: 1542090240.0
#  theo_fpt: 55119.990902737314
#     tok/s: 3181.525497
#       mfu: 5.77%
# model: google/flan-t5-large, mb: 1
#       fpt: 4849895424.0
#  theo_fpt: 17526.151095830308
#     tok/s: 893.436509
#       mfu: 5.1%
# model: google/flan-t5-large, mb: 8
#       fpt: 4849895424.0
#  theo_fpt: 17526.151095830308
#     tok/s: 2506.042086
#       mfu: 14.3%
# model: google/flan-t5-large, mb: 16
#       fpt: 4849895424.0
#  theo_fpt: 17526.151095830308
#     tok/s: 17639.401975
#       mfu: 100.65%

# %%
full_df
# Out:
#               model_name  minibatch_size  tokens_per_s     params  n_layers  \
# 0   google/flan-t5-small               1    287.046447   76961152         8
# 1   google/flan-t5-small               8    370.270828   76961152         8
# 2   google/flan-t5-small              16    592.968843   76961152         8
# 3   google/flan-t5-small              32   1104.413837   76961152         8
# 4   google/flan-t5-small              64   2146.452256   76961152         8
# 5   google/flan-t5-small             128   4283.432291   76961152         8
# 6    google/flan-t5-base               1    417.595299  247577856        12
# 7    google/flan-t5-base               8    900.732014  247577856        12
# 8    google/flan-t5-base              16   1638.849320  247577856        12
# 9    google/flan-t5-base              32   3181.525497  247577856        12
# 10  google/flan-t5-large               1    893.436509  783150080        24
# 11  google/flan-t5-large               8   2506.042086  783150080        24
# 12  google/flan-t5-large              16  17639.401975  783150080        24
#
#     d_model  d_ff  n_attention_heads  seq_len         mfu
# 0       512  1024                  8      512    0.164438
# 1       512  1024                  8      512    0.212114
# 2       512  1024                  8      512    0.339689
# 3       512  1024                  8      512    0.632677
# 4       512  1024                  8      512    1.229621
# 5       512  1024                  8      512    2.453816
# 6       768  2048                 12      512    0.757611
# 7       768  2048                 12      512    1.634129
# 8       768  2048                 12      512    2.973239
# 9       768  2048                 12      512    5.771999
# 10     1024  2816                 16      512    5.097734
# 11     1024  2816                 16      512   14.298873
# 12     1024  2816                 16      512  100.646182

# %%
fig, ax = plt.subplots(1,1)

temp_df = full_df.query("mfu < 60").copy() # filter faulty t5-large mfu reading

fig = sns.barplot(
    data=temp_df,
    x="minibatch_size",
    y="mfu",
    hue="model_name",
    ax=ax)
show_barplot_values(ax)
fig.set_ylabel("Model Flops Utilization in %")
fig.set_xlabel("Minibatch Size")
ax.legend(title="Model Name", loc="upper right")
fig.set_title("Model Flop Utilization for Orin AGX")
# Out:
# Text(0.5, 1.0, 'Model Flop Utilization for Orin AGX')
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
