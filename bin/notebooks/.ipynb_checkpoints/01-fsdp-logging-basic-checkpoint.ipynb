# %%
import os
import pandas as pd
import seaborn as sns
from pathlib import Path
from tbparse import SummaryReader
from matplotlib import pyplot as plt
from IPython.display import display
# Out:
# 2023-09-26 18:33:55.924657: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-26 18:33:55.959475: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-26 18:33:55.960091: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-26 18:33:56.570932: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## 0.0 Plotting Settings

# %%
pd.set_option('display.max_rows', 200)
plotting_context = "paper"
default_palette = "colorblind"
font_scale = 1.5
sns.set(font_scale=font_scale, context=plotting_context)
sns.set(rc={"figure.dpi":300, 'savefig.dpi':300})

# %% [markdown]
# ## 0.1 Glue Code To Load Logs

# %%
LOG_DIR = "es-04-logs/.tb_logs"
log_path = Path(os.getcwd()) / Path(LOG_DIR)

def to_group_name(s):
    name = s.split("-")
    return name[0] + "-" + name[1]

def to_global_rank(s):
    if "CAI" in s:
        return s.split("-")[3][1:]
    else:
        return s.split("-")[2][1:]

def get_run_logs(log_path):
    reader = SummaryReader(log_path, extra_columns={"dir_name"}, pivot=True)
    
    config_df = reader.text
    config_df = config_df.drop("step", axis=1)
    config_df = config_df.rename(columns={"dir_name": "run_name"})
    config_df["group_name"] = config_df["run_name"].apply(lambda x: to_group_name(x))
    config_df["global_rank"] = config_df["run_name"].apply(lambda x: to_global_rank(x))
    
    display(config_df)
    
    runs_df = reader.tensors
    runs_df = runs_df.rename(columns={"dir_name": "run_name"})
    runs_df["group_name"] = runs_df["run_name"].apply(lambda x: to_group_name(x))
    runs_df["global_rank"] = runs_df["run_name"].apply(lambda x: to_global_rank(x))
    
    minibatch_label = "minibatch_size"
    runs_df[minibatch_label] = "0"
    for gname in runs_df["group_name"].unique():
        
        value = config_df.query(f"group_name=='{gname}'")["00_cfg/batch_size"].iloc[0]
        if isinstance(value,list):
            minibatch_value = value[0]
        else:
            minibatch_value = int(value)
        runs_df.loc[
            runs_df.group_name == gname,
            minibatch_label] = str(minibatch_value)
    return config_df, runs_df

# %% [markdown]
# ## 0.2 Helper Visualization Functions

# %%
def set_fontsizes(small=8, medium=10, bigger=12):
    SMALL_SIZE = small
    MEDIUM_SIZE = medium
    BIGGER_SIZE = bigger

    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
    
    plt.rcParams['legend.title_fontsize'] = MEDIUM_SIZE
    
def set_palette(value="default"):
    default_palette = "tab10"
    if value == "rocket":
        rocket_cmap = sns.color_palette("rocket", 20)
        sns.set(palette=rocket_cmap)
    elif value == "default":
        sns.set(palette=default_palette)
set_palette("default")

def save_figure(name, local_fig_dir=None, file_type='pdf'):
    '''Save matplotlib figures at a local directory based on the full hardcoded path
    :param name: str - name of the pdf figure (e.g., "throughput")
    :param local_fig_dir: str - plots are saved under this subdirectory
    '''
    figure_path   = "/home/asa/Documents/github-repos/thesis/ibm-blogpost-p1/figures"
    if local_fig_dir != None:
        full_fig_dir  = figure_path + "/" + local_fig_dir
    else:
        full_fig_dir = figure_path
    full_fig_path = full_fig_dir + "/" + name + "." + file_type
    dpi = 300
    plt.savefig(full_fig_path, dpi=dpi, bbox_inches = "tight")
    
def save_fig(name, file_type='pdf'):
    save_figure(name, file_type=file_type)

# %% [markdown]
# ## 0.3 Run Configuration For All Runs

# %%
config_df, runs_df = get_run_logs(log_path=log_path)
# Out:
#    00_cfg/backend 00_cfg/batch_size 00_cfg/config 00_cfg/cpu_core_count  \
# 0            nccl          [16, 16]          None                   NaN
# 1            nccl          [16, 16]          None                   NaN
# 2            nccl          [32, 32]          None                   NaN
# 3            nccl          [32, 32]          None                   NaN
# 4            nccl          [48, 48]          None                   NaN
# 5            nccl          [48, 48]          None                   NaN
# 6            nccl          [64, 64]          None                   NaN
# 7            nccl          [64, 64]          None                   NaN
# 8            nccl            [8, 8]          None                   NaN
# 9            nccl            [8, 8]          None                   NaN
# 10           nccl          [88, 88]          None                   NaN
# 11           nccl          [88, 88]          None                   NaN
# 12           nccl          [98, 98]          None                   NaN
# 13           nccl          [98, 98]          None                   NaN
# 14            NaN                 8           NaN                   128
# 15            NaN                 8           NaN                   128
# 16            NaN                16           NaN                   128
# 17            NaN                16           NaN                   128
# 18            NaN                73           NaN                   128
# 19            NaN                73           NaN                   128
# 20            NaN                 8           NaN                   128
# 21            NaN                 8           NaN                   128
# 22            NaN                16           NaN                   128
# 23            NaN                16           NaN                   128
# 24            NaN                32           NaN                   128
# 25            NaN                32           NaN                   128
# 26            NaN                60           NaN                   128
# 27            NaN                60           NaN                   128
# 28            NaN                 8           NaN                   128
# 29            NaN                 8           NaN                   128
# 30            NaN                16           NaN                   128
# 31            NaN                16           NaN                   128
# 32            NaN                32           NaN                   128
# 33            NaN                32           NaN                   128
# 34            NaN                44           NaN                   128
# 35            NaN                44           NaN                   128
# 36            NaN                48           NaN                   128
# 37            NaN                48           NaN                   128
# 38            NaN                32           NaN                   128
# 39            NaN                32           NaN                   128
# 40            NaN                 8           NaN                   128
# 41            NaN                 8           NaN                   128
# 42            NaN                16           NaN                   128
# 43            NaN                16           NaN                   128
# 44            NaN                32           NaN                   128
# 45            NaN                32           NaN                   128
# 46            NaN                44           NaN                   128
# 47            NaN                44           NaN                   128
# 48            NaN                48           NaN                   128
# 49            NaN                48           NaN                   128
# 50            NaN                64           NaN                   128
# 51            NaN                64           NaN                   128
# 52            NaN                64           NaN                   128
# 53            NaN                64           NaN                   128
# 54            NaN                69           NaN                   128
# 55            NaN                69           NaN                   128
# 56            NaN                 8           NaN                   128
# 57            NaN                 8           NaN                   128
# 58            NaN                16           NaN                   128
# 59            NaN                16           NaN                   128
# 60            NaN                32           NaN                   128
# 61            NaN                32           NaN                   128
# 62            NaN                64           NaN                   128
# 63            NaN                64           NaN                   128
# 64            NaN                69           NaN                   128
# 65            NaN                69           NaN                   128
#
#    00_cfg/cpu_offloading 00_cfg/cuda_version 00_cfg/distplan  \
# 0                    NaN                 NaN      CAI_Gemini
# 1                    NaN                 NaN      CAI_Gemini
# 2                    NaN                 NaN      CAI_Gemini
# 3                    NaN                 NaN      CAI_Gemini
# 4                    NaN                 NaN      CAI_Gemini
# 5                    NaN                 NaN      CAI_Gemini
# 6                    NaN                 NaN      CAI_Gemini
# 7                    NaN                 NaN      CAI_Gemini
# 8                    NaN                 NaN      CAI_Gemini
# 9                    NaN                 NaN      CAI_Gemini
# 10                   NaN                 NaN      CAI_Gemini
# 11                   NaN                 NaN      CAI_Gemini
# 12                   NaN                 NaN      CAI_Gemini
# 13                   NaN                 NaN      CAI_Gemini
# 14                 False                12.1             NaN
# 15                 False                12.1             NaN
# 16                 False                12.1             NaN
# 17                 False                12.1             NaN
# 18                 False                12.1             NaN
# 19                 False                12.1             NaN
# 20                 False                11.7             NaN
# 21                 False                11.7             NaN
# 22                 False                11.7             NaN
# 23                 False                11.7             NaN
# 24                 False                11.7             NaN
# 25                 False                11.7             NaN
# 26                 False                11.7             NaN
# 27                 False                11.7             NaN
# 28                 False                11.7             NaN
# 29                 False                11.7             NaN
# 30                 False                11.7             NaN
# 31                 False                11.7             NaN
# 32                 False                11.7             NaN
# 33                 False                11.7             NaN
# 34                 False                11.7             NaN
# 35                 False                11.7             NaN
# 36                 False                11.7             NaN
# 37                 False                11.7             NaN
# 38                 False                12.1             NaN
# 39                 False                12.1             NaN
# 40                 False                12.1             NaN
# 41                 False                12.1             NaN
# 42                 False                12.1             NaN
# 43                 False                12.1             NaN
# 44                 False                12.1             NaN
# 45                 False                12.1             NaN
# 46                 False                12.1             NaN
# 47                 False                12.1             NaN
# 48                 False                12.1             NaN
# 49                 False                12.1             NaN
# 50                 False                12.1             NaN
# 51                 False                12.1             NaN
# 52                 False                12.1             NaN
# 53                 False                12.1             NaN
# 54                 False                12.1             NaN
# 55                 False                12.1             NaN
# 56                 False                12.1             NaN
# 57                 False                12.1             NaN
# 58                 False                12.1             NaN
# 59                 False                12.1             NaN
# 60                 False                12.1             NaN
# 61                 False                12.1             NaN
# 62                 False                12.1             NaN
# 63                 False                12.1             NaN
# 64                 False                12.1             NaN
# 65                 False                12.1             NaN
#
#    00_cfg/distributed_debug 00_cfg/driver_version 00_cfg/enable_profiler  ...  \
# 0                       NaN                   NaN                    NaN  ...
# 1                       NaN                   NaN                    NaN  ...
# 2                       NaN                   NaN                    NaN  ...
# 3                       NaN                   NaN                    NaN  ...
# 4                       NaN                   NaN                    NaN  ...
# 5                       NaN                   NaN                    NaN  ...
# 6                       NaN                   NaN                    NaN  ...
# 7                       NaN                   NaN                    NaN  ...
# 8                       NaN                   NaN                    NaN  ...
# 9                       NaN                   NaN                    NaN  ...
# 10                      NaN                   NaN                    NaN  ...
# 11                      NaN                   NaN                    NaN  ...
# 12                      NaN                   NaN                    NaN  ...
# 13                      NaN                   NaN                    NaN  ...
# 14                     True             535.54.03                  False  ...
# 15                     True             535.54.03                  False  ...
# 16                     True             535.54.03                  False  ...
# 17                     True             535.54.03                  False  ...
# 18                     True             535.54.03                  False  ...
# 19                     True             535.54.03                  False  ...
# 20                     True             535.54.03                  False  ...
# 21                     True             535.54.03                  False  ...
# 22                     True             535.54.03                  False  ...
# 23                     True             535.54.03                  False  ...
# 24                     True             535.54.03                  False  ...
# 25                     True             535.54.03                  False  ...
# 26                     True             535.54.03                  False  ...
# 27                     True             535.54.03                  False  ...
# 28                     True             535.54.03                  False  ...
# 29                     True             535.54.03                  False  ...
# 30                     True             535.54.03                  False  ...
# 31                     True             535.54.03                  False  ...
# 32                     True             535.54.03                  False  ...
# 33                     True             535.54.03                  False  ...
# 34                     True             535.54.03                  False  ...
# 35                     True             535.54.03                  False  ...
# 36                     True             535.54.03                  False  ...
# 37                     True             535.54.03                  False  ...
# 38                     True             535.54.03                  False  ...
# 39                     True             535.54.03                  False  ...
# 40                     True             535.54.03                  False  ...
# 41                     True             535.54.03                  False  ...
# 42                     True             535.54.03                  False  ...
# 43                     True             535.54.03                  False  ...
# 44                     True             535.54.03                  False  ...
# 45                     True             535.54.03                  False  ...
# 46                     True             535.54.03                  False  ...
# 47                     True             535.54.03                  False  ...
# 48                     True             535.54.03                  False  ...
# 49                     True             535.54.03                  False  ...
# 50                     True             535.54.03                  False  ...
# 51                     True             535.54.03                  False  ...
# 52                     True             535.54.03                  False  ...
# 53                     True             535.54.03                  False  ...
# 54                     True             535.54.03                  False  ...
# 55                     True             535.54.03                  False  ...
# 56                     True             535.54.03                  False  ...
# 57                     True             535.54.03                  False  ...
# 58                     True             535.54.03                  False  ...
# 59                     True             535.54.03                  False  ...
# 60                     True             535.54.03                  False  ...
# 61                     True             535.54.03                  False  ...
# 62                     True             535.54.03                  False  ...
# 63                     True             535.54.03                  False  ...
# 64                     True             535.54.03                  False  ...
# 65                     True             535.54.03                  False  ...
#
#    00_cfg/tokenizer     00_cfg/torch_version 00_cfg/total_memory_sys_MB  \
# 0               NaN                      NaN                        NaN
# 1               NaN                      NaN                        NaN
# 2               NaN                      NaN                        NaN
# 3               NaN                      NaN                        NaN
# 4               NaN                      NaN                        NaN
# 5               NaN                      NaN                        NaN
# 6               NaN                      NaN                        NaN
# 7               NaN                      NaN                        NaN
# 8               NaN                      NaN                        NaN
# 9               NaN                      NaN                        NaN
# 10              NaN                      NaN                        NaN
# 11              NaN                      NaN                        NaN
# 12              NaN                      NaN                        NaN
# 13              NaN                      NaN                        NaN
# 14         t5-large  2.2.0.dev20230915+cu121             2151130.144768
# 15         t5-large  2.2.0.dev20230915+cu121             2151130.144768
# 16         t5-large  2.2.0.dev20230915+cu121             2151130.144768
# 17         t5-large  2.2.0.dev20230915+cu121             2151130.144768
# 18         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 19         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 20         t5-large             1.13.0+cu117             2151130.124288
# 21         t5-large             1.13.0+cu117             2151130.124288
# 22         t5-large             1.13.0+cu117             2151130.124288
# 23         t5-large             1.13.0+cu117             2151130.124288
# 24         t5-large             1.13.0+cu117             2151130.124288
# 25         t5-large             1.13.0+cu117             2151130.124288
# 26         t5-large             1.13.0+cu117             2151130.124288
# 27         t5-large             1.13.0+cu117             2151130.124288
# 28                              1.13.0+cu117             2151130.124288
# 29                              1.13.0+cu117             2151130.124288
# 30                              1.13.0+cu117             2151130.124288
# 31                              1.13.0+cu117             2151130.124288
# 32                              1.13.0+cu117             2151130.124288
# 33                              1.13.0+cu117             2151130.124288
# 34                              1.13.0+cu117             2151130.124288
# 35                              1.13.0+cu117             2151130.124288
# 36                              1.13.0+cu117             2151130.124288
# 37                              1.13.0+cu117             2151130.124288
# 38         t5-large  2.2.0.dev20230915+cu121             2151130.144768
# 39         t5-large  2.2.0.dev20230915+cu121             2151130.144768
# 40                   2.2.0.dev20230915+cu121             2151130.124288
# 41                   2.2.0.dev20230915+cu121             2151130.124288
# 42                   2.2.0.dev20230915+cu121             2151130.124288
# 43                   2.2.0.dev20230915+cu121             2151130.124288
# 44                   2.2.0.dev20230915+cu121             2151130.124288
# 45                   2.2.0.dev20230915+cu121             2151130.124288
# 46                   2.2.0.dev20230915+cu121             2151130.124288
# 47                   2.2.0.dev20230915+cu121             2151130.124288
# 48                   2.2.0.dev20230915+cu121             2151130.124288
# 49                   2.2.0.dev20230915+cu121             2151130.124288
# 50                   2.2.0.dev20230915+cu121             2151130.124288
# 51                   2.2.0.dev20230915+cu121             2151130.124288
# 52         t5-large  2.2.0.dev20230915+cu121             2151130.144768
# 53         t5-large  2.2.0.dev20230915+cu121             2151130.144768
# 54         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 55         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 56         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 57         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 58         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 59         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 60         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 61         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 62         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 63         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 64         t5-large  2.2.0.dev20230915+cu121             2151130.124288
# 65         t5-large  2.2.0.dev20230915+cu121             2151130.124288
#
#    00_cfg/train_step 00_cfg/use_fp16 00_cfg/use_mixed_precision  \
# 0                 50             NaN                        NaN
# 1                 50             NaN                        NaN
# 2                 50             NaN                        NaN
# 3                 50             NaN                        NaN
# 4                 50             NaN                        NaN
# 5                 50             NaN                        NaN
# 6                 50             NaN                        NaN
# 7                 50             NaN                        NaN
# 8                 50             NaN                        NaN
# 9                 50             NaN                        NaN
# 10                50             NaN                        NaN
# 11                50             NaN                        NaN
# 12                50             NaN                        NaN
# 13                50             NaN                        NaN
# 14               NaN            True                       True
# 15               NaN            True                       True
# 16               NaN            True                       True
# 17               NaN            True                       True
# 18               NaN            True                       True
# 19               NaN            True                       True
# 20               NaN            True                       True
# 21               NaN            True                       True
# 22               NaN            True                       True
# 23               NaN            True                       True
# 24               NaN            True                       True
# 25               NaN            True                       True
# 26               NaN            True                       True
# 27               NaN            True                       True
# 28               NaN            True                       True
# 29               NaN            True                       True
# 30               NaN            True                       True
# 31               NaN            True                       True
# 32               NaN            True                       True
# 33               NaN            True                       True
# 34               NaN            True                       True
# 35               NaN            True                       True
# 36               NaN            True                       True
# 37               NaN            True                       True
# 38               NaN            True                       True
# 39               NaN            True                       True
# 40               NaN            True                       True
# 41               NaN            True                       True
# 42               NaN            True                       True
# 43               NaN            True                       True
# 44               NaN            True                       True
# 45               NaN            True                       True
# 46               NaN            True                       True
# 47               NaN            True                       True
# 48               NaN            True                       True
# 49               NaN            True                       True
# 50               NaN            True                       True
# 51               NaN            True                       True
# 52               NaN            True                       True
# 53               NaN            True                       True
# 54               NaN            True                       True
# 55               NaN            True                       True
# 56               NaN            True                       True
# 57               NaN            True                       True
# 58               NaN            True                       True
# 59               NaN            True                       True
# 60               NaN            True                       True
# 61               NaN            True                       True
# 62               NaN            True                       True
# 63               NaN            True                       True
# 64               NaN            True                       True
# 65               NaN            True                       True
#
#    00_cfg/world_size             run_name     group_name global_rank
# 0               None  CAI_Gemini-16-50-r0  CAI_Gemini-16           0
# 1               None  CAI_Gemini-16-50-r1  CAI_Gemini-16           1
# 2               None  CAI_Gemini-32-50-r0  CAI_Gemini-32           0
# 3               None  CAI_Gemini-32-50-r1  CAI_Gemini-32           1
# 4               None  CAI_Gemini-48-50-r0  CAI_Gemini-48           0
# 5               None  CAI_Gemini-48-50-r1  CAI_Gemini-48           1
# 6               None  CAI_Gemini-64-50-r0  CAI_Gemini-64           0
# 7               None  CAI_Gemini-64-50-r1  CAI_Gemini-64           1
# 8               None   CAI_Gemini-8-50-r0   CAI_Gemini-8           0
# 9               None   CAI_Gemini-8-50-r1   CAI_Gemini-8           1
# 10              None  CAI_Gemini-88-50-r0  CAI_Gemini-88           0
# 11              None  CAI_Gemini-88-50-r1  CAI_Gemini-88           1
# 12              None  CAI_Gemini-98-50-r0  CAI_Gemini-98           0
# 13              None  CAI_Gemini-98-50-r1  CAI_Gemini-98           1
# 14               NaN            FSDP-0-r0         FSDP-0           0
# 15               NaN            FSDP-0-r1         FSDP-0           1
# 16               NaN            FSDP-1-r0         FSDP-1           0
# 17               NaN            FSDP-1-r1         FSDP-1           1
# 18               NaN           FSDP-10-r0        FSDP-10           0
# 19               NaN           FSDP-10-r1        FSDP-10           1
# 20               NaN           FSDP-11-r0        FSDP-11           0
# 21               NaN           FSDP-11-r1        FSDP-11           1
# 22               NaN           FSDP-12-r0        FSDP-12           0
# 23               NaN           FSDP-12-r1        FSDP-12           1
# 24               NaN           FSDP-13-r0        FSDP-13           0
# 25               NaN           FSDP-13-r1        FSDP-13           1
# 26               NaN           FSDP-14-r0        FSDP-14           0
# 27               NaN           FSDP-14-r1        FSDP-14           1
# 28               NaN           FSDP-15-r0        FSDP-15           0
# 29               NaN           FSDP-15-r1        FSDP-15           1
# 30               NaN           FSDP-16-r0        FSDP-16           0
# 31               NaN           FSDP-16-r1        FSDP-16           1
# 32               NaN           FSDP-17-r0        FSDP-17           0
# 33               NaN           FSDP-17-r1        FSDP-17           1
# 34               NaN           FSDP-18-r0        FSDP-18           0
# 35               NaN           FSDP-18-r1        FSDP-18           1
# 36               NaN           FSDP-19-r0        FSDP-19           0
# 37               NaN           FSDP-19-r1        FSDP-19           1
# 38               NaN            FSDP-2-r0         FSDP-2           0
# 39               NaN            FSDP-2-r1         FSDP-2           1
# 40               NaN           FSDP-20-r0        FSDP-20           0
# 41               NaN           FSDP-20-r1        FSDP-20           1
# 42               NaN           FSDP-21-r0        FSDP-21           0
# 43               NaN           FSDP-21-r1        FSDP-21           1
# 44               NaN           FSDP-22-r0        FSDP-22           0
# 45               NaN           FSDP-22-r1        FSDP-22           1
# 46               NaN           FSDP-23-r0        FSDP-23           0
# 47               NaN           FSDP-23-r1        FSDP-23           1
# 48               NaN           FSDP-24-r0        FSDP-24           0
# 49               NaN           FSDP-24-r1        FSDP-24           1
# 50               NaN           FSDP-25-r0        FSDP-25           0
# 51               NaN           FSDP-25-r1        FSDP-25           1
# 52               NaN            FSDP-3-r0         FSDP-3           0
# 53               NaN            FSDP-3-r1         FSDP-3           1
# 54               NaN            FSDP-4-r0         FSDP-4           0
# 55               NaN            FSDP-4-r1         FSDP-4           1
# 56               NaN            FSDP-5-r0         FSDP-5           0
# 57               NaN            FSDP-5-r1         FSDP-5           1
# 58               NaN            FSDP-6-r0         FSDP-6           0
# 59               NaN            FSDP-6-r1         FSDP-6           1
# 60               NaN            FSDP-7-r0         FSDP-7           0
# 61               NaN            FSDP-7-r1         FSDP-7           1
# 62               NaN            FSDP-8-r0         FSDP-8           0
# 63               NaN            FSDP-8-r1         FSDP-8           1
# 64               NaN            FSDP-9-r0         FSDP-9           0
# 65               NaN            FSDP-9-r1         FSDP-9           1
#
# [66 rows x 57 columns]

# %%
runs = ["CAI_Gemini-8"]

config_df.query(f"group_name in {runs}")[["00_cfg/batch_size", "00_cfg/model_name"]]
# Out:
#   00_cfg/batch_size 00_cfg/model_name
# 8            [8, 8]               NaN
# 9            [8, 8]               NaN

# %%
config_df.columns
# Out:
# Index(['00_cfg/backend', '00_cfg/batch_size', '00_cfg/config',
#        '00_cfg/cpu_core_count', '00_cfg/cpu_offloading', '00_cfg/cuda_version',
#        '00_cfg/distplan', '00_cfg/distributed_debug', '00_cfg/driver_version',
#        '00_cfg/enable_profiler', '00_cfg/fsdp_activation_checkpointing',
#        '00_cfg/gpu_0_id', '00_cfg/gpu_0_name', '00_cfg/gpu_0_pci_cur_link',
#        '00_cfg/gpu_0_pci_cur_link_width', '00_cfg/gpu_0_pci_max_link',
#        '00_cfg/gpu_0_pci_max_link_width', '00_cfg/gpu_0_vbios_version',
#        '00_cfg/gpu_1_id', '00_cfg/gpu_1_name', '00_cfg/gpu_1_pci_cur_link',
#        '00_cfg/gpu_1_pci_cur_link_width', '00_cfg/gpu_1_pci_max_link',
#        '00_cfg/gpu_1_pci_max_link_width', '00_cfg/gpu_1_vbios_version',
#        '00_cfg/gpu_count', '00_cfg/gpu_num', '00_cfg/host', '00_cfg/host_port',
#        '00_cfg/local_rank', '00_cfg/max_step_count', '00_cfg/max_steps',
#        '00_cfg/memory_snapshot_step', '00_cfg/memory_snapshotting',
#        '00_cfg/model_checkpoint', '00_cfg/model_name', '00_cfg/model_type',
#        '00_cfg/nccl_debug_handler', '00_cfg/nccl_version', '00_cfg/num_epochs',
#        '00_cfg/num_workers_dataloader', '00_cfg/port',
#        '00_cfg/print_sharding_plan', '00_cfg/rank', '00_cfg/save_model',
#        '00_cfg/seed', '00_cfg/sharding_strategy', '00_cfg/tokenizer',
#        '00_cfg/torch_version', '00_cfg/total_memory_sys_MB',
#        '00_cfg/train_step', '00_cfg/use_fp16', '00_cfg/use_mixed_precision',
#        '00_cfg/world_size', 'run_name', 'group_name', 'global_rank'],
#       dtype='object')

# %%
config = "00_cfg/sharding_strategy"
run_name = "FSDP-12-r0"
print(f"{run_name}[{config}]:",config_df.query(f"run_name=='{run_name}'")[config].values)
# Out:
# FSDP-12-r0[00_cfg/sharding_strategy]: ['FULL_SHARD']

# %%
runs_df.query(f"group_name=='FSDP-20'").head(10)
# Out:
#       step  01_general/epoch  01_general/loss  01_general/sps  \
# 1974     0               1.0        11.140625        0.926290
# 1975     1               1.0        11.148438        3.054065
# 1976     2               1.0        11.156250        3.867745
# 1977     3               1.0        11.148438        3.835460
# 1978     4               1.0        11.304688        4.010995
# 1979     5               1.0        11.210938        4.011232
# 1980     6               1.0        11.203125        4.006704
# 1981     7               1.0        11.164062        4.102769
# 1982     8               1.0        11.195312        4.002616
# 1983     9               1.0        11.203125        4.017152
#
#       01_general/step  01_general/tokens_per_s  02_timing/actual_step_time_s  \
# 1974              1.0               948.521362                      8.636600
# 1975              2.0              3127.362793                      2.619459
# 1976              3.0              3960.571289                      2.068388
# 1977              4.0              3927.510742                      2.085799
# 1978              5.0              4107.259277                      1.994517
# 1979              6.0              4107.501465                      1.994400
# 1980              7.0              4102.864746                      1.996654
# 1981              8.0              4201.235352                      1.949903
# 1982              9.0              4098.678711                      1.998693
# 1983             10.0              4113.563477                      1.991461
#
#       02_timing/backward_time_s  02_timing/calculated_step_time_s  \
# 1974                   2.624608                          8.356209
# 1975                   1.309015                          2.529509
# 1976                   1.310732                          1.973966
# 1977                   1.313027                          1.974877
# 1978                   1.313860                          1.879332
# 1979                   1.314676                          1.881167
# 1980                   1.314343                          1.881771
# 1981                   1.315323                          1.882737
# 1982                   1.316587                          1.883896
# 1983                   1.315414                          1.882175
#
#       02_timing/dataload_cuda_mode_time_s  ...  \
# 1974                             0.000009  ...
# 1975                             0.000007  ...
# 1976                             0.000006  ...
# 1977                             0.000007  ...
# 1978                             0.000006  ...
# 1979                             0.000006  ...
# 1980                             0.000006  ...
# 1981                             0.000007  ...
# 1982                             0.000006  ...
# 1983                             0.000006  ...
#
#      process/memory/lib_memory_proc_MB  \
# 1974                       1839.259644
# 1975                       1913.663452
# 1976                       1916.817383
# 1977                       1917.222900
# 1978                       1917.784058
# 1979                       1917.792236
# 1980                       1917.820923
# 1981                       1917.820923
# 1982                       1917.820923
# 1983                       1917.820923
#
#       process/memory/resident_set_size_proc_MB  \
# 1974                               1372.041260
# 1975                               1428.086792
# 1976                               1431.404541
# 1977                               1431.732178
# 1978                               1432.293335
# 1979                               1432.317993
# 1980                               1432.363037
# 1981                               1432.379395
# 1982                               1432.391724
# 1983                               1432.399902
#
#       process/memory/shared_memory_proc_MB  \
# 1974                            337.604614
# 1975                            341.303284
# 1976                            341.303284
# 1977                            341.303284
# 1978                            341.303284
# 1979                            341.303284
# 1980                            341.303284
# 1981                            341.303284
# 1982                            341.303284
# 1983                            341.303284
#
#       process/memory/text_resident_set_proc_MB  \
# 1974                                   2.17088
# 1975                                   2.17088
# 1976                                   2.17088
# 1977                                   2.17088
# 1978                                   2.17088
# 1979                                   2.17088
# 1980                                   2.17088
# 1981                                   2.17088
# 1982                                   2.17088
# 1983                                   2.17088
#
#       process/memory/virtual_memory_size_proc_MB  \
# 1974                                40467.804688
# 1975                                40542.101562
# 1976                                45981.066406
# 1977                                45981.460938
# 1978                                45981.609375
# 1979                                45981.609375
# 1980                                45981.609375
# 1981                                45981.609375
# 1982                                45981.609375
# 1983                                45981.609375
#
#       process/voluntary_proc_ctx_switches    run_name  group_name  \
# 1974                              36202.0  FSDP-20-r0     FSDP-20
# 1975                              36846.0  FSDP-20-r0     FSDP-20
# 1976                              37255.0  FSDP-20-r0     FSDP-20
# 1977                              37650.0  FSDP-20-r0     FSDP-20
# 1978                              38065.0  FSDP-20-r0     FSDP-20
# 1979                              38478.0  FSDP-20-r0     FSDP-20
# 1980                              38886.0  FSDP-20-r0     FSDP-20
# 1981                              39292.0  FSDP-20-r0     FSDP-20
# 1982                              39708.0  FSDP-20-r0     FSDP-20
# 1983                              40119.0  FSDP-20-r0     FSDP-20
#
#       global_rank  minibatch_size
# 1974            0               8
# 1975            0               8
# 1976            0               8
# 1977            0               8
# 1978            0               8
# 1979            0               8
# 1980            0               8
# 1981            0               8
# 1982            0               8
# 1983            0               8
#
# [10 rows x 199 columns]

# %% [markdown]
# ## Preprocess Log DataFrame

# %%
steps_in_epoch = runs_df["01_general/step"].max()
runs_df.loc[:, "global_step"] = runs_df["01_general/step"] +  ((runs_df["01_general/epoch"] - 1) * steps_in_epoch)

# %%
for col in runs_df.columns:
    print(col)
# Out:
# step
# 01_general/epoch
# 01_general/loss
# 01_general/sps
# 01_general/step
# 01_general/tokens_per_s
# 02_timing/actual_step_time_s
# 02_timing/backward_time_s
# 02_timing/calculated_step_time_s
# 02_timing/dataload_cuda_mode_time_s
# 02_timing/dataload_time_s
# 02_timing/forward_time_s
# 02_timing/opt_step_time_s
# 02_timing/running_epoch_time_s
# 02_timing/running_training_time_s
# 02_timing/zero_grad_time_s
# 03_gpu_mem/active.all.allocated
# 03_gpu_mem/active.all.current
# 03_gpu_mem/active.all.freed
# 03_gpu_mem/active.all.peak
# 03_gpu_mem/active.large_pool.allocated
# 03_gpu_mem/active.large_pool.current
# 03_gpu_mem/active.large_pool.freed
# 03_gpu_mem/active.large_pool.peak
# 03_gpu_mem/active.small_pool.allocated
# 03_gpu_mem/active.small_pool.current
# 03_gpu_mem/active.small_pool.freed
# 03_gpu_mem/active.small_pool.peak
# 03_gpu_mem/active_bytes.all.allocated
# 03_gpu_mem/active_bytes.all.current
# 03_gpu_mem/active_bytes.all.freed
# 03_gpu_mem/active_bytes.all.peak
# 03_gpu_mem/active_bytes.large_pool.allocated
# 03_gpu_mem/active_bytes.large_pool.current
# 03_gpu_mem/active_bytes.large_pool.freed
# 03_gpu_mem/active_bytes.large_pool.peak
# 03_gpu_mem/active_bytes.small_pool.allocated
# 03_gpu_mem/active_bytes.small_pool.current
# 03_gpu_mem/active_bytes.small_pool.freed
# 03_gpu_mem/active_bytes.small_pool.peak
# 03_gpu_mem/allocated_bytes.all.allocated
# 03_gpu_mem/allocated_bytes.all.current
# 03_gpu_mem/allocated_bytes.all.freed
# 03_gpu_mem/allocated_bytes.all.peak
# 03_gpu_mem/allocated_bytes.large_pool.allocated
# 03_gpu_mem/allocated_bytes.large_pool.current
# 03_gpu_mem/allocated_bytes.large_pool.freed
# 03_gpu_mem/allocated_bytes.large_pool.peak
# 03_gpu_mem/allocated_bytes.small_pool.allocated
# 03_gpu_mem/allocated_bytes.small_pool.current
# 03_gpu_mem/allocated_bytes.small_pool.freed
# 03_gpu_mem/allocated_bytes.small_pool.peak
# 03_gpu_mem/allocation.all.allocated
# 03_gpu_mem/allocation.all.current
# 03_gpu_mem/allocation.all.freed
# 03_gpu_mem/allocation.all.peak
# 03_gpu_mem/allocation.large_pool.allocated
# 03_gpu_mem/allocation.large_pool.current
# 03_gpu_mem/allocation.large_pool.freed
# 03_gpu_mem/allocation.large_pool.peak
# 03_gpu_mem/allocation.small_pool.allocated
# 03_gpu_mem/allocation.small_pool.current
# 03_gpu_mem/allocation.small_pool.freed
# 03_gpu_mem/allocation.small_pool.peak
# 03_gpu_mem/inactive_split.all.allocated
# 03_gpu_mem/inactive_split.all.current
# 03_gpu_mem/inactive_split.all.freed
# 03_gpu_mem/inactive_split.all.peak
# 03_gpu_mem/inactive_split.large_pool.allocated
# 03_gpu_mem/inactive_split.large_pool.current
# 03_gpu_mem/inactive_split.large_pool.freed
# 03_gpu_mem/inactive_split.large_pool.peak
# 03_gpu_mem/inactive_split.small_pool.allocated
# 03_gpu_mem/inactive_split.small_pool.current
# 03_gpu_mem/inactive_split.small_pool.freed
# 03_gpu_mem/inactive_split.small_pool.peak
# 03_gpu_mem/inactive_split_bytes.all.allocated
# 03_gpu_mem/inactive_split_bytes.all.current
# 03_gpu_mem/inactive_split_bytes.all.freed
# 03_gpu_mem/inactive_split_bytes.all.peak
# 03_gpu_mem/inactive_split_bytes.large_pool.allocated
# 03_gpu_mem/inactive_split_bytes.large_pool.current
# 03_gpu_mem/inactive_split_bytes.large_pool.freed
# 03_gpu_mem/inactive_split_bytes.large_pool.peak
# 03_gpu_mem/inactive_split_bytes.small_pool.allocated
# 03_gpu_mem/inactive_split_bytes.small_pool.current
# 03_gpu_mem/inactive_split_bytes.small_pool.freed
# 03_gpu_mem/inactive_split_bytes.small_pool.peak
# 03_gpu_mem/max_split_size
# 03_gpu_mem/num_alloc_retries
# 03_gpu_mem/num_ooms
# 03_gpu_mem/oversize_allocations.allocated
# 03_gpu_mem/oversize_allocations.current
# 03_gpu_mem/oversize_allocations.freed
# 03_gpu_mem/oversize_allocations.peak
# 03_gpu_mem/oversize_segments.allocated
# 03_gpu_mem/oversize_segments.current
# 03_gpu_mem/oversize_segments.freed
# 03_gpu_mem/oversize_segments.peak
# 03_gpu_mem/requested_bytes.all.allocated
# 03_gpu_mem/requested_bytes.all.current
# 03_gpu_mem/requested_bytes.all.freed
# 03_gpu_mem/requested_bytes.all.peak
# 03_gpu_mem/requested_bytes.large_pool.allocated
# 03_gpu_mem/requested_bytes.large_pool.current
# 03_gpu_mem/requested_bytes.large_pool.freed
# 03_gpu_mem/requested_bytes.large_pool.peak
# 03_gpu_mem/requested_bytes.small_pool.allocated
# 03_gpu_mem/requested_bytes.small_pool.current
# 03_gpu_mem/requested_bytes.small_pool.freed
# 03_gpu_mem/requested_bytes.small_pool.peak
# 03_gpu_mem/reserved_bytes.all.allocated
# 03_gpu_mem/reserved_bytes.all.current
# 03_gpu_mem/reserved_bytes.all.freed
# 03_gpu_mem/reserved_bytes.all.peak
# 03_gpu_mem/reserved_bytes.large_pool.allocated
# 03_gpu_mem/reserved_bytes.large_pool.current
# 03_gpu_mem/reserved_bytes.large_pool.freed
# 03_gpu_mem/reserved_bytes.large_pool.peak
# 03_gpu_mem/reserved_bytes.small_pool.allocated
# 03_gpu_mem/reserved_bytes.small_pool.current
# 03_gpu_mem/reserved_bytes.small_pool.freed
# 03_gpu_mem/reserved_bytes.small_pool.peak
# 03_gpu_mem/segment.all.allocated
# 03_gpu_mem/segment.all.current
# 03_gpu_mem/segment.all.freed
# 03_gpu_mem/segment.all.peak
# 03_gpu_mem/segment.large_pool.allocated
# 03_gpu_mem/segment.large_pool.current
# 03_gpu_mem/segment.large_pool.freed
# 03_gpu_mem/segment.large_pool.peak
# 03_gpu_mem/segment.small_pool.allocated
# 03_gpu_mem/segment.small_pool.current
# 03_gpu_mem/segment.small_pool.freed
# 03_gpu_mem/segment.small_pool.peak
# 04_agg_gpu/allocation_rounding_overhead_bytes
# 04_agg_gpu/avg_block_size_current_bytes
# 04_agg_gpu/avg_inactive_block_size_current_bytes
# 04_agg_gpu/avg_large_segment_size_current_bytes
# 04_agg_gpu/avg_segment_size_current_bytes
# 04_agg_gpu/avg_small_segment_size_current_bytes
# 04_agg_gpu/memory_fragmentation_ratio
# 05_gpu_smi/gpu_0_bar1_free_MiB
# 05_gpu_smi/gpu_0_bar1_total_MiB
# 05_gpu_smi/gpu_0_bar1_used_MiB
# 05_gpu_smi/gpu_0_clocks_throttle_reason_applications_clocks_setting
# 05_gpu_smi/gpu_0_clocks_throttle_reason_gpu_idle
# 05_gpu_smi/gpu_0_clocks_throttle_reason_hw_slowdown
# 05_gpu_smi/gpu_0_clocks_throttle_reason_sw_power_cap
# 05_gpu_smi/gpu_0_fb_free_MiB
# 05_gpu_smi/gpu_0_fb_total_MiB
# 05_gpu_smi/gpu_0_fb_used_MiB
# 05_gpu_smi/gpu_0_gpu_util_in_percent
# 05_gpu_smi/gpu_0_mem_util_in_percent
# 05_gpu_smi/gpu_0_temp_in_C
# 05_gpu_smi/gpu_1_bar1_free_MiB
# 05_gpu_smi/gpu_1_bar1_total_MiB
# 05_gpu_smi/gpu_1_bar1_used_MiB
# 05_gpu_smi/gpu_1_clocks_throttle_reason_applications_clocks_setting
# 05_gpu_smi/gpu_1_clocks_throttle_reason_gpu_idle
# 05_gpu_smi/gpu_1_clocks_throttle_reason_hw_slowdown
# 05_gpu_smi/gpu_1_clocks_throttle_reason_sw_power_cap
# 05_gpu_smi/gpu_1_fb_free_MiB
# 05_gpu_smi/gpu_1_fb_total_MiB
# 05_gpu_smi/gpu_1_fb_used_MiB
# 05_gpu_smi/gpu_1_gpu_util_in_percent
# 05_gpu_smi/gpu_1_mem_util_in_percent
# 05_gpu_smi/gpu_1_temp_in_C
# bandwidth/disk_read_sys_bandwidth_MBs
# bandwidth/disk_write_sys_bandwidth_MBs
# bandwidth/net_recv_sys_bandwidth_Mbits
# bandwidth/net_sent_sys_bandwidth_Mbits
# cpu/interrupts/ctx_switches_count
# cpu/interrupts/interrupts_count
# cpu/interrupts/soft_interrupts_count
# cpu/load/avg_sys_load_fifteen_min_percent
# cpu/load/avg_sys_load_five_min_percent
# cpu/load/avg_sys_load_one_min_percent
# disk/counter/disk_read_sys_count
# disk/counter/disk_write_sys_count
# disk/time/disk_busy_time_sys_s
# disk/time/disk_read_time_sys_s
# disk/time/disk_write_time_sys_s
# memory/available_memory_sys_MB
# memory/used_memory_sys_MB
# memory/used_memory_sys_percent
# process/involuntary_proc_ctx_switches
# process/memory/data_resident_set_proc_MB
# process/memory/dirty_pages_proc_count
# process/memory/lib_memory_proc_MB
# process/memory/resident_set_size_proc_MB
# process/memory/shared_memory_proc_MB
# process/memory/text_resident_set_proc_MB
# process/memory/virtual_memory_size_proc_MB
# process/voluntary_proc_ctx_switches
# run_name
# group_name
# global_rank
# minibatch_size
# global_step

# %% [markdown]
# ## Experiment Count

# %%
print(f"Experiment Count: {len(config_df['group_name'].unique())}")
print(config_df['group_name'].unique())
# Out:
# Experiment Count: 33
# ['CAI_Gemini-16' 'CAI_Gemini-32' 'CAI_Gemini-48' 'CAI_Gemini-64'
#  'CAI_Gemini-8' 'CAI_Gemini-88' 'CAI_Gemini-98' 'FSDP-0' 'FSDP-1'
#  'FSDP-10' 'FSDP-11' 'FSDP-12' 'FSDP-13' 'FSDP-14' 'FSDP-15' 'FSDP-16'
#  'FSDP-17' 'FSDP-18' 'FSDP-19' 'FSDP-2' 'FSDP-20' 'FSDP-21' 'FSDP-22'
#  'FSDP-23' 'FSDP-24' 'FSDP-25' 'FSDP-3' 'FSDP-4' 'FSDP-5' 'FSDP-6'
#  'FSDP-7' 'FSDP-8' 'FSDP-9']

# %% [markdown]
# ## 1.0 Selective Metrics View

# %%
def show_barplot_values(ax, decimals=2):
    
    max_y = 0
    for (p_ix, p) in enumerate(ax.patches):
        #if p_ix >= (len(ax.patches) / 2):
        #p_ix = p_ix - (len(ax.patches) / 2)
        _x = p.get_x() + p.get_width() / 2
        _y = p.get_y() + (p.get_height() * 1.05)
        max_y = max(max_y, _y)
        if decimals == 2:
            value = '{:.2f}'.format(_y)
        elif decimals == 1:
            value = '{:.1f}'.format(_y)
        elif decimals == 0:
            value = '{:.0f}'.format(_y)
        ax.text(_x, _y, value, ha="center")
        
    visualized_max_y = max_y * 1.10
    ax.set_ylim([0, visualized_max_y])

def dual_plot(df, x, y, line_ylim=None, figsize=(8,2), title=None, rotation=90, decimals=2):
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=figsize)
    ax1 = sns.barplot(
        data=df,
        x=x,
        y=y,
        ax=ax1,
        errorbar=("ci", 95),
        errwidth=1,
        capsize=0.08)
    ax1.set_xticklabels(df[x].unique(), rotation=rotation)#, ha='right')
    show_barplot_values(ax = ax1, decimals=decimals)
    ax2 = sns.lineplot(
        data=df,
        x="step",
        y=y,
        ax=ax2,
        hue=x)
    ax2.set_ylabel("")
    ax2.set_ylim(line_ylim)
    if title != None:
        fig.suptitle(title)
    return ax1, ax2

set_fontsizes(8,8,8)

valid_runs = [
    "FSDP-0",
    "FSDP-1",
    "FSDP-2",
    "FSDP-3",
    "FSDP-4",
#    "FSDP-25"
]

temp_df = runs_df.copy().query(f"group_name in {valid_runs}")

#x = "group_name"
x = "minibatch_size"
y = "01_general/tokens_per_s"
ax1, ax2 = dual_plot(df=temp_df, x=x, y=y, rotation=0, decimals=0)
ax1.set_ylabel("Tokens per Second")
ax1.set_xlabel("Minibatch Size")
ax2.set_xlabel("Step")
ax1.set_ylim(0,5000)
ax2.set_ylim(0,5000)
ax2.legend_.remove()
save_fig("t5-3b-tokens-per-second-default")
# Out:
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ##  1.1 Step Timing Of All Runs

# %%
set_fontsizes(10,12,14)

def get_average_step_timings(df):
    mean_df = df.mean(numeric_only=True).to_frame().T
    mean_df["run_name"] = df["run_name"].unique()[0][:-3]
    mean_df = mean_df.rename(columns={
                            #"02_timing/dataload_time_s": "dataload_time_s",
                            #"02_timing/dataload_cuda_mode_time_s": "dataload_cuda_mode_time_s",
                            #"02_timing/zero_grad_time_s": "zero_grad_time_s",
                            "02_timing/forward_time_s": "forward_time_s",
                            "02_timing/backward_time_s": "backward_time_s",
                            #"02_timing/opt_step_time_s": "opt_step_time_s",
                            #"logging_penalty_per_step_s": "logging_penalty_s"
                            })
    
    exported_labels = [
        #"dataload_time_s",
        #"dataload_cuda_mode_time_s",
        #"zero_grad_time_s",
        "forward_time_s",
        "backward_time_s",
        #"opt_step_time_s",
        #"logging_penalty_s",
        "run_name"]
    return mean_df[exported_labels], exported_labels

timings = []

valid_runs = [
    "FSDP-20",
    "FSDP-21",
    "FSDP-22",
    #"FSDP-23",
    "FSDP-24",
    "FSDP-25",
    #"CAI_Gemini-8",
    #"CAI_Gemini-16",
    #"CAI_Gemini-32",
    #"CAI_Gemini-48",
    #"CAI_Gemini-64",
    #"CAI_Gemini-88",
    #"CAI_Gemini-98",
]

temp_df = runs_df.copy().query(f"group_name in {valid_runs}")

for run_name in temp_df["run_name"].unique():
    single_run = temp_df.query(f"run_name=='{run_name}'")
    if not ("r1" in run_name):
        avg_step_timing_df, exported_labels = get_average_step_timings(df=single_run)
        timings.append(avg_step_timing_df)

all_step_timings_df = pd.concat(objs=timings)
all_step_timings_df = all_step_timings_df.sort_values(by=["backward_time_s"])
ax = all_step_timings_df[exported_labels].set_index("run_name").plot(kind="bar", stacked=True, figsize=(9,2))
plt.ylabel("Time in Seconds")
plt.xlabel("")
plt.title("Inter-step Training Timing")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1,1))
show_barplot_values(ax=ax, decimals=1)
ax.set_xticklabels(all_step_timings_df["run_name"].unique(), rotation=25)
# Out:
# [Text(0, 0, 'FSDP-20'),
#  Text(1, 0, 'FSDP-21'),
#  Text(2, 0, 'FSDP-22'),
#  Text(3, 0, 'FSDP-24'),
#  Text(4, 0, 'FSDP-25')]

# %% [markdown]
# ## GPU Memory Statistics

# %%
def plot_complex_metrics(
    data,
    name,
    ax,
    convert_to_mill=True,
    full_metrics=False):
    
    if convert_to_mill:
        denominator = 1000**2
        if "bytes" in name:
            y_label = name.replace("_bytes", "in MB")
        else:
            y_label = name + " in 1M"
    else:
        denominator = 1
        if "bytes" in name:
            y_label = name.replace("_bytes", " in Byte")
        else:
            y_label = name + " count"
    
    if "oversize_allocations" in name or \
           "oversize_segments" in name:
        postfix = "."
    else:
        postfix = ".all."
    
    x  = data["step"].reset_index(drop=True)
    y1 = data[f"03_gpu_mem/{name}{postfix}allocated"].reset_index(drop=True) / denominator
    y2 = data[f"03_gpu_mem/{name}{postfix}current"].reset_index(drop=True) / denominator
    y3 = data[f"03_gpu_mem/{name}{postfix}freed"].reset_index(drop=True) / denominator
    y4 = data[f"03_gpu_mem/{name}{postfix}peak"].reset_index(drop=True) / denominator

    legend_handles = []
    if full_metrics:
        y1_h,  = ax.plot(x, y1, linestyle="dashed", label="allocated")
        y3_h, = ax.plot(x, y3, linestyle='dashdot', label="free")
        legend_handles.append(y1_h)
        legend_handles.append(y3_h)
    y2_h, = ax.plot(x, y2, linestyle='dotted', label="current", linewidth=1)
    y4_h, = ax.plot(x, y4, linestyle='solid', label="peak", linewidth=1)
    legend_handles.append(y2_h)
    legend_handles.append(y4_h)

    ax.set_xlabel("Global Step")
    ax.set_ylabel(y_label)
    ax.legend(handles=legend_handles)

# %%
#temp_df = runs_df.query("run_name=='CAI_Gemini-92-2-20'").copy()
temp_df = runs_df.query("run_name=='FSDP-21-r0'").copy()

set_fontsizes(4,6,8)
fig, axs = plt.subplots(4, 5, figsize=(8, 5), layout='constrained')
gpu_metrics = [
    "active",
    "active_bytes",
    "inactive_split",
    "inactive_split_bytes",
    "oversize_allocations",
    "oversize_segments",
    "allocated_bytes",
    "requested_bytes",
    "reserved_bytes", 
    "segment",
    "03_gpu_mem/max_split_size",
    "03_gpu_mem/num_alloc_retries",
    "03_gpu_mem/num_ooms",
    #"04_agg_gpu/allocation_rounding_overhead_bytes",
    #"04_agg_gpu/avg_block_size_current_bytes",
    #"04_agg_gpu/avg_inactive_block_size_current_bytes",
    #"04_agg_gpu/avg_segment_size_current_bytes",
    #"04_agg_gpu/avg_large_segment_size_current_bytes",
    #"04_agg_gpu/avg_small_segment_size_current_bytes",
    "04_agg_gpu/memory_fragmentation_ratio"
    
]
gpu_metrics_ax_map = list(zip(gpu_metrics, axs.flat))

for name, ax in gpu_metrics_ax_map:
    if "/" in name:
        
        y_label = name.replace("03_gpu_mem/", "")
        y_label = y_label.replace("04_agg_gpu/", "")
        
        if "bytes" in name:
            temp_df.loc[:, f"{y_label}_mb"] = temp_df[name] / 1000**2

            ax = sns.lineplot(
                data=temp_df,
                x="step",
                y=f"{y_label}_mb",
                ax=ax,
            )
            y_label = y_label.replace("_bytes", "")
            ax.set_ylabel(f"{y_label} in MB")
        else:
            ax = sns.lineplot(
                    data=temp_df,
                    x="step",
                    y=name,
                    ax=ax,
                )

            ax.set_ylabel(y_label)

        ax.set_xlabel("Global Step")
    else:
        plot_complex_metrics(
            data=temp_df,
            name=name,
            ax=ax)

# %%
set_fontsizes(8,8,10)

valid_runs = [
    "FSDP-0",
    "FSDP-1",
    "FSDP-2",
    "FSDP-3",
    "FSDP-4",
#    "FSDP-24",
#    "FSDP-25",
]

temp_df = runs_df.copy().query(f"group_name in {valid_runs} and global_rank=='0'")
x = "minibatch_size"
y = "04_agg_gpu/memory_fragmentation_ratio"
ax1, ax2 = dual_plot(df=temp_df, x=x, y=y, rotation=0)#, title="Memory Fragmentation Ratio (Higher = Better)", rotation=0)
ax1.set_xlabel("Minibatch Size")
ax1.set_ylabel("Allocated / Total Block Size")
ax2.set_xlabel("Step")
ax2.legend_.remove()
save_fig("t5-3b-memory-fragmentation-default")
# Out:
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
set_fontsizes(8,8,8)
valid_runs = [
    "FSDP-0",
    "FSDP-1",
    "FSDP-2",
    "FSDP-3",
    "FSDP-4",
]
temp_df = runs_df.copy().query(f"group_name in {valid_runs} and global_rank=='0'")

temp_df["reserved_gb.all_current"] = temp_df["03_gpu_mem/reserved_bytes.all.current"] / 1024**3
x = "minibatch_size"
y = "reserved_gb.all_current"
#with sns.plotting_context(context="notebook"):
ax1, ax2 = dual_plot(df=temp_df, x=x, y=y, decimals=1, rotation=0)
ax1.set_ylabel("Reserved Memory in GiB")
ax1.set_xlabel("Minibatch Size")
ax2.set_xlabel("Step")
ax2.legend_.remove()
save_fig("t5-3b-memory-consumption-default")
# Out:
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
set_fontsizes(8,8,8)
valid_runs = [
    "FSDP-0",
    "FSDP-1",
    "FSDP-2",
    "FSDP-3",
    "FSDP-4",
    
]

temp_df = runs_df.copy().query(f"group_name in {valid_runs} and global_rank=='0'")
#temp_df["avg_segment_size_MB"] = temp_df["04_agg_gpu/avg_large_segment_size_current_bytes"] / 1000**2
x = "minibatch_size"
y1 = "01_general/tokens_per_s"
y2 = "03_gpu_mem/num_alloc_retries"

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(8,2))

sns.barplot(
    data=temp_df,
    x=x,
    y=y1,
    hue=x,
    ax=ax2,
    errorbar=("ci", 95),
    errwidth=1,
    capsize=0.08,
    dodge=False
)
ax2.set_xlabel("Minibatch Size")
ax2.set_ylabel("Tokens per Second")
ax2.legend_.remove()
show_barplot_values(ax = ax2, decimals=0)
sns.lineplot(
    data=temp_df,
    x="step",
    y=y2,
    hue=x,
    ax=ax1
)
ax1.set_ylabel("cudaAllocation Retries")
ax1.set_xlabel("Step")
ax1.legend_.remove()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
set_fontsizes(8,8,8)
valid_runs = [
    "FSDP-0",
    "FSDP-1",
    "FSDP-2",
    "FSDP-3",
    "FSDP-4",
    
]

temp_df = runs_df.copy().query(f"group_name in {valid_runs} and global_rank=='0'")
x = "minibatch_size"
y = "03_gpu_mem/num_alloc_retries"

fig, ax = plt.subplots(figsize=(8,4))
                       
sns.lineplot(
    data=temp_df,
    x="step",
    y=y,
    hue=x,
    ax=ax
)
ax.set_ylabel("cudaAllocation Retries")
ax.set_xlabel("Step")
plt.legend(title="Minibatch Size")
save_fig("t5-3b-cuda-allocation-retries-default")
#ax.legend_.remove()
# Out:
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
def show_barplot_values(ax, decimals=0):
    
    max_y = 0
    for (p_ix, p) in enumerate(ax.patches):
        #if p_ix >= (len(ax.patches) / 2):
        #p_ix = p_ix - (len(ax.patches) / 2)
        _x = p.get_x() + p.get_width() / 2
        _y = p.get_y() + (p.get_height() * 1.05)
        max_y = max(max_y, _y)
        if decimals == 2:
            value = '{:.2f}'.format(_y)
        elif decimals == 1:
            value = '{:.1f}'.format(_y)
        elif decimals == 0:
            value = '{:.0f}'.format(_y)
        ax.text(_x, _y, value, ha="center", rotation=20)
        
    visualized_max_y = max_y * 1.10
    ax.set_ylim([0, visualized_max_y])

def speed_mem_plot(df, x, figsize=(8,2.5), title=None, names=None):
    
    df["reserved_gb.all_current"] = df["03_gpu_mem/reserved_bytes.all.current"] / 1024**3
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize=figsize)
    ax1 = sns.barplot(
        data=df,
        x=x,
        y="01_general/tokens_per_s",
        ax=ax1,
        errorbar=("ci", 95),
        errwidth=1,
        capsize=0.08)
    if names==None:
        ax1.set_xticklabels(df[x].unique(), rotation=90)#, ha='right')
    else:
        ax1.set_xticklabels(names, rotation=90)#, ha='right')
    #ax1.set_xlabel("Minibatch Size")
    ax1.set_xlabel("Setting + Rank")
    ax1.set_ylabel("")
    ax1.set_title("Tokens per Second")
    show_barplot_values(ax = ax1)
    
    ax2 = sns.lineplot(
        data=df,
        x="step",
        y="reserved_gb.all_current",
        ax=ax2,
        hue=x)
    ax2.set_title("Reserved Memory in GB")
    ax2.set_ylabel("")
    ax2.set_xlabel("Step")
    ax2.legend_.remove()

    ax3 = sns.lineplot(
        data=df,
        x="step",
        y="04_agg_gpu/memory_fragmentation_ratio",
        ax=ax3,
        hue=x)
    ax3.set_title("Memory Fragmentation Ratio")
    ax3.set_ylabel("")
    ax3.set_xlabel("Step")
    ax3.legend_.remove()

    
    ax4 = sns.lineplot(
        data=df,
        x="step",
        y="03_gpu_mem/num_alloc_retries",
        ax=ax4,
        hue=x)
    ax4.set_title("cudaAlloc Retries")
    ax4.set_ylabel("")
    ax4.legend_.remove()
    ax4.set_xlabel("Step")
    
    #ax2.set_ylim(line_ylim)
    if title != None:
        fig.suptitle(title)
        
    fig.tight_layout()
    return ax1, ax2, ax3, ax4


set_fontsizes(7,8,8)

valid_runs = [
    "FSDP-0",
    "FSDP-5"
]

#valid_runs = [
#    "FSDP-15",
#    "FSDP-16",
#    "FSDP-17",
    #"FSDP-23",
#    "FSDP-19",
#    "FSDP-25",
#]

#valid_runs = [
#    "CAI_Gemini-8",
#    "CAI_Gemini-16",
#    "CAI_Gemini-32",
#    "CAI_Gemini-48",
#    "CAI_Gemini-64",
#    "CAI_Gemini-88",
#    "CAI_Gemini-98",
#]

temp_df = runs_df.copy().query(f"group_name in {valid_runs}")# and global_rank=='0'")
#temp_df = temp_df.sort_values(by=["03_gpu_mem/reserved_bytes.all.current"])

#x = "minibatch_size"
x = "run_name"
names=["Default R0", "Default R1", "Exp-Seg. R0", "Exp-Seg. R1"]
ax1, ax2, ax3, ax4 = speed_mem_plot(df=temp_df, x=x, names=names)
save_fig("t5-3b-mb8-comparison")
# Out:
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/asa/miniconda3/envs/fsdp-mem/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# ONLY GROUP NAME, as each rank logs the CUDA API for ALL gpus
temp_df = runs_df.query("run_name=='FSDP-63-r0'").copy()

def get_gpu_count(df):
    # filter by column count of temp_in_C as we log all metrics on a single process
    return len([ix for ix in df.columns if ix.endswith("temp_in_C")])

gpu_count = get_gpu_count(df = temp_df)
set_fontsizes(4,6,8)
fig, axs = plt.subplots(gpu_count, 5, figsize=(10, 5), layout='constrained')

gpu_smi_group_key = "05_gpu_smi/"

throttle_causes = [
    "",
    "",
    "",
    "clocks_throttle_reason_sw_power_cap"
]

def plot_throttle_reason(data, prefix, y_label, ax):
    
    x  = data["global_step"].reset_index(drop=True)
    y1 = data[f"{gpu_smi_group_key}{prefix}clocks_throttle_reason_applications_clocks_setting"].reset_index(drop=True)
    y2 = data[f"{gpu_smi_group_key}{prefix}clocks_throttle_reason_gpu_idle"].reset_index(drop=True)
    y3 = data[f"{gpu_smi_group_key}{prefix}clocks_throttle_reason_hw_slowdown"].reset_index(drop=True)
    y4 = data[f"{gpu_smi_group_key}{prefix}clocks_throttle_reason_sw_power_cap"].reset_index(drop=True)
    
    legend_handles = []
    
    y1_h, = ax.plot(x, y1, linestyle="dashed", label="app_clock_setting", linewidth=1)
    y2_h, = ax.plot(x, y2, linestyle='solid', label="idle", linewidth=1)
    y3_h, = ax.plot(x, y3, linestyle='dashdot', label="hw_slow", linewidth=1)
    y4_h, = ax.plot(x, y4, linestyle='dotted', label="sw_power_cap", linewidth=1)
    
    legend_handles.append(y1_h)
    legend_handles.append(y2_h)
    legend_handles.append(y3_h)
    legend_handles.append(y4_h)

    ax.set_xlabel("Global Step")
    ax.set_ylabel(y_label)
    ax.legend(handles=legend_handles)
    

def plot_smi_memory(data, prefix, used_key, total_key, free_key, y_label, ax):
    x  = data["global_step"].reset_index(drop=True)
    y1 = data[f"{gpu_smi_group_key}{prefix}{used_key}"].reset_index(drop=True)
    y2 = data[f"{gpu_smi_group_key}{prefix}{free_key}"].reset_index(drop=True)
    y3 = data[f"{gpu_smi_group_key}{prefix}{total_key}"].reset_index(drop=True)

    legend_handles = []
    
    y1_h, = ax.plot(x, y1, linestyle="dashed", label="used", linewidth=1)
    y2_h, = ax.plot(x, y2, linestyle='dashdot', label="free", linewidth=1)
    y3_h, = ax.plot(x, y3, linestyle='solid', label="total", linewidth=1)
    legend_handles.append(y1_h)
    legend_handles.append(y2_h)
    legend_handles.append(y3_h)

    ax.set_xlabel("Global Step")
    ax.set_ylabel(y_label)
    ax.legend(handles=legend_handles)

for gpu_nr in range(gpu_count):
    
    prefix = f"gpu_{gpu_nr}_"
    # we have a gpu x 5 grid
    index = gpu_nr * 5

    ax = axs.flat[index]
    plot_smi_memory(
        data=temp_df,
        prefix=prefix,
        used_key="fb_used_MiB",
        total_key="fb_total_MiB",
        free_key="fb_free_MiB",
        y_label="Framebuffer in MiB",
        ax=ax
    )

    index = index + 1
    ax = axs.flat[index]
    plot_smi_memory(
        data=temp_df,
        prefix=prefix,
        used_key="bar1_used_MiB",
        total_key="bar1_total_MiB",
        free_key="bar1_free_MiB",
        y_label="BAR1 in MiB",
        ax=ax
    )
    
    index = index + 1
    ax = axs.flat[index]
    ax = sns.lineplot(
        data=temp_df,
        x="global_step",
        y=f"{gpu_smi_group_key}{prefix}gpu_util_in_percent",
        ax=ax,
    )
    ax.set_ylim([0,110])
    ax.set_ylabel("GPU Utilization in %")
    
    index = index + 1
    ax = axs.flat[index]
    ax = sns.lineplot(
        data=temp_df,
        x="global_step",
        y=f"{gpu_smi_group_key}{prefix}temp_in_C",
        ax=ax,
    )
    ax.set_ylim([0,100])
    ax.set_ylabel("GPU Temp in C")
    
    index = index + 1
    ax = axs.flat[index]
    plot_throttle_reason(
        data=temp_df,
        prefix=prefix,
        y_label="Throttle Reasons",
        ax=ax
    )
